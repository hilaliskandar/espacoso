# %% [markdown]
# # A3 — OLS e diagnóstico espacial
# Execute a fixture e o pipeline, depois compare `baseline` e `expanded`.

# %%
from pathlib import Path
from diagnostico_ols.pipeline import run_pipeline
import subprocess, sys
subprocess.run([sys.executable, '../scripts/create_demo_data.py', '--output-dir', '../data/demo'], check=True)
products = run_pipeline('../config/demo.yml')
products
