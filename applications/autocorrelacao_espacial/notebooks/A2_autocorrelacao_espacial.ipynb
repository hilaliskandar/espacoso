# %% [markdown]
# # A2 — Matrizes de pesos e autocorrelação espacial
# Este caderno executa a demonstração reproduzível e orienta a comparação entre rook, queen, k-vizinhos e distância.

# %%
from pathlib import Path
from autocorrelacao_espacial.config import load_config
from autocorrelacao_espacial.pipeline import run_pipeline

# %%
config_path = Path('../config/demo.yml').resolve()
config = load_config(config_path)
result = run_pipeline(config, config_path)
result['output_dir']

# %% [markdown]
# Compare `sensibilidade_matrizes.csv` e os mapas. Diferenças entre matrizes devem ser interpretadas como diferenças entre hipóteses de interação espacial, não como escolha automática do resultado mais significativo.
